# %%
import pandas as pd
df = pd.read_csv('CricketTestData.csv')
df
# Out:
#    Player;Span;Mat;Inns;NO;Runs;HS;Ave;BF;SR;100;50;0;4s;6s
# 0   DG Bradman (AUS);1928-1948;52;80;10;6996;334;9...
# 1   HC Brook (ENG);2022-2023;12;20;1;1181;186;62.1...
# 2   AC Voges (AUS);2015-2016;20;31;7;1485;269*;61....
# 3   RG Pollock (SA);1963-1970;23;41;4;2256;274;60....
# 4   GA Headley (WI);1930-1954;22;40;4;2190;270*;60...
# ..                                                ...
# 57  KD Walters (AUS);1965-1981;74;125;14;5357;250;...
# 58  GC Smith (ICC/SA);2002-2014;117;205;13;9265;27...
# 59  WH Ponsford (AUS);1924-1934;29;48;4;2122;266;4...
# 60  SJ McCabe (AUS);1930-1938;39;62;5;2748;232;48....
# 61  DR Jardine (ENG);1928-1934;22;33;6;1296;127;48...
#
# [62 rows x 1 columns]

# %%
df = pd.read_csv('CricketTestData.csv', delimiter=';')
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7   626   6
# ...

# %%
df = df.rename(columns={'Mat':'Matches','NO':'Not_Outs','HS':'Highest_Inns_Score','BF':'Balls_Faced','SR':'Batting_Strike_Rate  '})
df.head()
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1    HC Brook (ENG)  2022-2023       12    20         1  1181
# 2    AC Voges (AUS)  2015-2016       20    31         7  1485
# 3   RG Pollock (SA)  1963-1970       23    41         4  2256
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
#
#   Highest_Inns_Score    Ave Balls_Faced Batting_Strike_Rate    100  50  0  \
# 0                334  99.94       9800+                 58.60   29  13  7
# 1                186  62.15        1287                 91.76    4   7  1
# 2               269*  61.87        2667                 55.68    5   4  2
# 3                274  60.97       1707+                 54.48    7  11  1
# 4               270*  60.83        416+                 56.00   10   5  2
#
#     4s  6s
# 0  626   6
# 1  141  23
# 2  186   5
# 3  246  11
# 4  104   1

# %%
df.isnull().any()
df[df['Balls_Faced'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Span, Matches, Inns, Not_Outs, Runs, Highest_Inns_Score, Ave, Balls_Faced, Batting_Strike_Rate  , 100, 50, 0, 4s, 6s]
# Index: []

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# Length: 62, dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Span, Matches, Inns, Not_Outs, Runs, Highest_Inns_Score, Ave, Balls_Faced, Batting_Strike_Rate  , 100, 50, 0, 4s, 6s]
# Index: []

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df[df['Player'].duplicated()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Span, Matches, Inns, Not_Outs, Runs, Highest_Inns_Score, Ave, Balls_Faced, Batting_Strike_Rate  , 100, 50, 0, 4s, 6s]
# Index: []

# %%
df.drop_duplicates()
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1      HC Brook (ENG)  2022-2023       12    20         1  1181
# 2      AC Voges (AUS)  2015-2016       20    31         7  1485
# 3     RG Pollock (SA)  1963-1970       23    41         4  2256
# 4     GA Headley (WI)  1930-1954       22    40         4  2190
# ..                ...        ...      ...   ...       ...   ...
# 57   KD Walters (AUS)  1965-1981       74   125        14  5357
# 58  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 59  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 60    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 61   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced Batting_Strike_Rate    100  50   0  \
# 0                 334  99.94       9800+                 58.60   29  13   7
# ...

# %%
df[df['Player'].isin(['DG Bradman (AUS'])]
# Out:
# Empty DataFrame
# Columns: [Player, Span, Matches, Inns, Not_Outs, Runs, Highest_Inns_Score, Ave, Balls_Faced, Batting_Strike_Rate  , 100, 50, 0, 4s, 6s]
# Index: []

# %%
df['Span']
# Out:
# 0     1928-1948
# 1     2022-2023
# 2     2015-2016
# 3     1963-1970
# 4     1930-1954
#         ...
# 57    1965-1981
# 58    2002-2014
# 59    1924-1934
# 60    1930-1938
# 61    1928-1934
# Name: Span, Length: 62, dtype: object

# %%
df['Span'].str.split(pat=',')
# Out:
# 0     [1928-1948]
# 1     [2022-2023]
# 2     [2015-2016]
# 3     [1963-1970]
# 4     [1930-1954]
#          ...
# 57    [1965-1981]
# 58    [2002-2014]
# 59    [1924-1934]
# 60    [1930-1938]
# 61    [1928-1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Span'].str.split(pat='-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 57    [1965, 1981]
# 58    [2002, 2014]
# 59    [1924, 1934]
# 60    [1930, 1938]
# 61    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Span'].str.split(pat='-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 57    [1965, 1981]
# 58    [2002, 2014]
# 59    [1924, 1934]
# 60    [1930, 1938]
# 61    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Span']
# Out:
# 0     1928-1948
# 1     2022-2023
# 2     2015-2016
# 3     1963-1970
# 4     1930-1954
#         ...
# 57    1965-1981
# 58    2002-2014
# 59    1924-1934
# 60    1930-1938
# 61    1928-1934
# Name: Span, Length: 62, dtype: object

# %%
df['Final_Year']= df['Span'].str.split(pat='-').str[1]

# %%
df['Rookie_Year']= df['Span'].str.split(pat='-').str[0]

# %%
df.head()
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1    HC Brook (ENG)  2022-2023       12    20         1  1181
# 2    AC Voges (AUS)  2015-2016       20    31         7  1485
# 3   RG Pollock (SA)  1963-1970       23    41         4  2256
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
#
#   Highest_Inns_Score    Ave Balls_Faced Batting_Strike_Rate    100  50  0  \
# 0                334  99.94       9800+                 58.60   29  13  7
# 1                186  62.15        1287                 91.76    4   7  1
# 2               269*  61.87        2667                 55.68    5   4  2
# 3                274  60.97       1707+                 54.48    7  11  1
# 4               270*  60.83        416+                 56.00   10   5  2
#
#     4s  6s Final_Year Rookie_Year
# 0  626   6       1948        1928
# 1  141  23       2023        2022
# 2  186   5       2016        2015
# ...

# %%
df = df.drop(['Span'],axis=1)

# %%
df.head()
# Out:
#              Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0  DG Bradman (AUS)       52    80        10  6996                334  99.94
# 1    HC Brook (ENG)       12    20         1  1181                186  62.15
# 2    AC Voges (AUS)       20    31         7  1485               269*  61.87
# 3   RG Pollock (SA)       23    41         4  2256                274  60.97
# 4   GA Headley (WI)       22    40         4  2190               270*  60.83
#
#   Balls_Faced Batting_Strike_Rate    100  50  0   4s  6s Final_Year  \
# 0       9800+                 58.60   29  13  7  626   6       1948
# 1        1287                 91.76    4   7  1  141  23       2023
# 2        2667                 55.68    5   4  2  186   5       2016
# 3       1707+                 54.48    7  11  1  246  11       1970
# 4        416+                 56.00   10   5  2  104   1       1954
#
#   Rookie_Year
# 0        1928
# 1        2022
# 2        2015
# 3        1963
# 4        1930

# %%
df['Player'].str.split(pat='(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [HC Brook , ENG)]
# 2        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [GA Headley , WI)]
#               ...
# 57     [KD Walters , AUS)]
# 58    [GC Smith , ICC/SA)]
# 59    [WH Ponsford , AUS)]
# 60      [SJ McCabe , AUS)]
# 61     [DR Jardine , ENG)]
# Name: Player, Length: 62, dtype: object

# %%
df['Country'] = df['Player'].str.split(pat='(').str[1]

# %%
df['Country']  = df['Country'].str.split(pat=')').str[0]

# %%
df['Player'] = df['Player'].str.split(pat= '(').str[0]

# %%
df.head()
# Out:
#         Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0  DG Bradman        52    80        10  6996                334  99.94
# 1    HC Brook        12    20         1  1181                186  62.15
# 2    AC Voges        20    31         7  1485               269*  61.87
# 3  RG Pollock        23    41         4  2256                274  60.97
# 4  GA Headley        22    40         4  2190               270*  60.83
#
#   Balls_Faced Batting_Strike_Rate    100  50  0   4s  6s Final_Year  \
# 0       9800+                 58.60   29  13  7  626   6       1948
# 1        1287                 91.76    4   7  1  141  23       2023
# 2        2667                 55.68    5   4  2  186   5       2016
# 3       1707+                 54.48    7  11  1  246  11       1970
# 4        416+                 56.00   10   5  2  104   1       1954
#
#   Rookie_Year Country
# 0        1928     AUS
# 1        2022     ENG
# 2        2015     AUS
# 3        1963      SA
# ...

# %%
df.dtypes
# Out:
# Player                    object
# Matches                    int64
# Inns                       int64
# Not_Outs                   int64
# Runs                       int64
# Highest_Inns_Score        object
# Ave                      float64
# Balls_Faced               object
# Batting_Strike_Rate       object
# 100                        int64
# 50                         int64
# 0                          int64
# 4s                         int64
# 6s                         int64
# Final_Year                object
# Rookie_Year               object
# Country                   object
# dtype: object

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].str.split(pat = '*').str[0]

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].astype('int')

# %%
df.dtypes
# Out:
# Player                    object
# Matches                    int64
# Inns                       int64
# Not_Outs                   int64
# Runs                       int64
# Highest_Inns_Score         int32
# Ave                      float64
# Balls_Faced               object
# Batting_Strike_Rate       object
# 100                        int64
# 50                         int64
# 0                          int64
# 4s                         int64
# 6s                         int64
# Final_Year                object
# Rookie_Year               object
# Country                   object
# dtype: object

# %%
df = df.astype({'Final_Year':'int','Rookie_Year':'int'})

# %%
df.dtypes
# Out:
# Player                    object
# Matches                    int64
# Inns                       int64
# Not_Outs                   int64
# Runs                       int64
# Highest_Inns_Score         int32
# Ave                      float64
# Balls_Faced               object
# Batting_Strike_Rate       object
# 100                        int64
# 50                         int64
# 0                          int64
# 4s                         int64
# 6s                         int64
# Final_Year                 int32
# Rookie_Year                int32
# Country                   object
# dtype: object

# %%
df.head()
# Out:
#         Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 0  DG Bradman        52    80        10  6996                 334  99.94
# 1    HC Brook        12    20         1  1181                 186  62.15
# 2    AC Voges        20    31         7  1485                 269  61.87
# 3  RG Pollock        23    41         4  2256                 274  60.97
# 4  GA Headley        22    40         4  2190                 270  60.83
#
#   Balls_Faced Batting_Strike_Rate    100  50  0   4s  6s  Final_Year  \
# 0       9800+                 58.60   29  13  7  626   6        1948
# 1        1287                 91.76    4   7  1  141  23        2023
# 2        2667                 55.68    5   4  2  186   5        2016
# 3       1707+                 54.48    7  11  1  246  11        1970
# 4        416+                 56.00   10   5  2  104   1        1954
#
#    Rookie_Year Country
# 0         1928     AUS
# 1         2022     ENG
# 2         2015     AUS
# ...

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.split(pat = '+').str[0]
df['Balls_Faced'] = df['Balls_Faced'].fillna('0').astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 2
#       1 df['Balls_Faced'] = df['Balls_Faced'].str.split(pat = '+').str[0]
# ----> 2 df['Balls_Faced'] = df['Balls_Faced'].fillna('0').astype(int)
#
# File c:\Users\Amer\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# ...

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.split('+').str[0]

def convert_to_int(value):
    try:
        return int(value)
    except ValueError:
        return 0

df['Balls_Faced'] = df['Balls_Faced'].apply(convert_to_int)

# %%
pd.set_option('display.max_rows',None)
df = df.drop(54,axis=0)

# %%
df
# Out:
#                Player  Matches  Inns  Not_Outs   Runs  Highest_Inns_Score  \
# 0         DG Bradman        52    80        10   6996                 334
# 1           HC Brook        12    20         1   1181                 186
# 2           AC Voges        20    31         7   1485                 269
# 3         RG Pollock        23    41         4   2256                 274
# 4         GA Headley        22    40         4   2190                 270
# 5        H Sutcliffe        54    84         9   4555                 194
# 6          E Paynter        20    31         5   1540                 243
# 7      KF Barrington        82   131        15   6806                 256
# 8          ED Weekes        48    81         5   4455                 207
# 9         WR Hammond        85   140        16   7249                 336
# 10         SPD Smith       106   189        24   9537                 239
# 11         GS Sobers        93   160        21   8032                 365
# ...

# %%
df.dtypes
# Out:
# Player                    object
# Matches                    int64
# Inns                       int64
# Not_Outs                   int64
# Runs                       int64
# Highest_Inns_Score         int32
# Ave                      float64
# Balls_Faced                int64
# Batting_Strike_Rate       object
# 100                        int64
# 50                         int64
# 0                          int64
# 4s                         int64
# 6s                         int64
# Final_Year                 int32
# Rookie_Year                int32
# Country                   object
# dtype: object

# %%
df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].fillna('0').astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Amer\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Batting_Strike_Rate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[107], line 1
# ...

# %%
df['career_lenght'] = df['Final_Year'] - df['Rookie_Year']

# %%
df.head()
# Out:
#         Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 0  DG Bradman        52    80        10  6996                 334  99.94
# 1    HC Brook        12    20         1  1181                 186  62.15
# 2    AC Voges        20    31         7  1485                 269  61.87
# 3  RG Pollock        23    41         4  2256                 274  60.97
# 4  GA Headley        22    40         4  2190                 270  60.83
#
#    Balls_Faced Batting_Strike_Rate    100  50  0   4s  6s  Final_Year  \
# 0         9800                 58.60   29  13  7  626   6        1948
# 1         1287                 91.76    4   7  1  141  23        2023
# 2         2667                 55.68    5   4  2  186   5        2016
# 3         1707                 54.48    7  11  1  246  11        1970
# 4          416                 56.00   10   5  2  104   1        1954
#
#    Rookie_Year Country  career_lenght
# 0         1928     AUS             20
# ...

# %%
df['career_lenght'].mean()
# Out:
# 13.163934426229508

# %%
df[df['career_lenght'] > 10]
df.head()
# Out:
#         Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 0  DG Bradman        52    80        10  6996                 334  99.94
# 1    HC Brook        12    20         1  1181                 186  62.15
# 2    AC Voges        20    31         7  1485                 269  61.87
# 3  RG Pollock        23    41         4  2256                 274  60.97
# 4  GA Headley        22    40         4  2190                 270  60.83
#
#    Balls_Faced Batting_Strike_Rate    100  50  0   4s  6s  Final_Year  \
# 0         9800                 58.60   29  13  7  626   6        1948
# 1         1287                 91.76    4   7  1  141  23        2023
# 2         2667                 55.68    5   4  2  186   5        2016
# 3         1707                 54.48    7  11  1  246  11        1970
# 4          416                 56.00   10   5  2  104   1        1954
#
#    Rookie_Year Country  career_lenght
# 0         1928     AUS             20
# ...
